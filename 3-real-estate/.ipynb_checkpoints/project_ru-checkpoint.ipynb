# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# Данное исследование ставит перед собой цель изучить ценообразование недвижимости в Санкт-Петербурге и соседних населенных пунктах, это позволить построить автоматизированную систему, которая сможет отслеживать аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# ## План работы

# %% [markdown]
# 1. Изучение общей информации о данных
# 2. Предобработка данных
#     1. Обработка пропущенных значений
#     2. Типы данных в таблицы
#     3. Устранение неявных дубликатов
# 3. Добавление новых столбцов
# 4. Исследовательский анализ данных
#     1. Изучение гистограмм
#     2. Изучение скорости продажи квартир
#     3. От чего зависит стоимость объекта
#     4. Стоимость в зависимости от населенного пункта
#     5. Стоимость в зависимости от удаленности от центра
# 5. Общий вывод

# %% [markdown]
# ### Изучим общую информацию о данных

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
df = pd.read_csv("./real_estate_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                           --------------  -----
#  0   total_images	last_price	total_area	first_day_exposition	rooms	ceiling_height	floors_total	living_area	floor	is_apartment	studio	open_plan	kitchen_area	balcony	locality_name	airports_nearest	cityCenters_nearest	parks_around3000	parks_nearest	ponds_around3000	ponds_nearest	days_exposition  23699 non-null  object
# dtypes: object(1)
# memory usage: 185.3+ KB

# %% [markdown]
# Исходя из метода `info()` видно что в данных собрана подробная информация о каждой квартире. В это входят фото, расположения, мебель, кол-во этажей и т.п. Попробуем вывести первый 10 строк для наглядности

# %%
display(df.head(10))
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...
# 5  10\t2890000.0\t30.4\t2018-09-10T00:00:00\t1\t\...
# 6  6\t3700000.0\t37.3\t2017-11-02T00:00:00\t1\t\t...
# 7  5\t7915000.0\t71.6\t2019-04-18T00:00:00\t2\t\t...
# 8  20\t2900000.0\t33.16\t2018-05-23T00:00:00\t1\t...
# 9  18\t5400000.0\t61.0\t2017-02-26T00:00:00\t3\t2...

# %% [markdown]
# Как видно данные разделены символом табуляции поэтому при чтении данных надо добавить разделитель `sep="\t"`

# %%
df = pd.read_csv("./real_estate_data.csv", sep="\t")
display(df.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# 1          11.0      2.0   посёлок Шушары           12817.0
# 2           8.3      0.0  Санкт-Петербург           21741.0
# 3           NaN      0.0  Санкт-Петербург           28098.0
# 4          41.0      NaN  Санкт-Петербург           31856.0
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.0               1.0          482.0               2.0
# 1             18603.0               0.0            NaN               0.0
# 2             13933.0               1.0           90.0               2.0
# 3              6800.0               2.0           84.0               3.0
# 4              8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Видно определённое количество пропусков в данных, которые необходимо будет обработать. Для наглядности построим гистограмму для всех данных

# %%
df.hist(figsize=(15, 20))
# Out:
# array([[<Axes: title={'center': 'total_images'}>,
#         <Axes: title={'center': 'last_price'}>,
#         <Axes: title={'center': 'total_area'}>,
#         <Axes: title={'center': 'rooms'}>],
#        [<Axes: title={'center': 'ceiling_height'}>,
#         <Axes: title={'center': 'floors_total'}>,
#         <Axes: title={'center': 'living_area'}>,
#         <Axes: title={'center': 'floor'}>],
#        [<Axes: title={'center': 'kitchen_area'}>,
#         <Axes: title={'center': 'balcony'}>,
#         <Axes: title={'center': 'airports_nearest'}>,
#         <Axes: title={'center': 'cityCenters_nearest'}>],
#        [<Axes: title={'center': 'parks_around3000'}>,
#         <Axes: title={'center': 'parks_nearest'}>,
#         <Axes: title={'center': 'ponds_around3000'}>,
#         <Axes: title={'center': 'ponds_nearest'}>],
#        [<Axes: title={'center': 'days_exposition'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# На некоторых графиках уже можно наблюдаться подобие распределения Пуассона или нормальное распределение. В остальных надо будет точечно подправить количество корзин либо провести иные корректировки. Осталось проверить на дубликаты

# %%
display(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Как видно дубликатов нет

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка пропущенных значений

# %% [markdown]
# Для того чтобы выявить пропущенные значения применим метод `.value_counts()`, который возвращает уникальные значения в столбце наряду с количеством этих уникальных значений.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# is_apartment            20924
# parks_nearest           15620
# ponds_nearest           14589
# balcony                 11519
# ceiling_height           9195
# airports_nearest         5542
# cityCenters_nearest      5519
# ponds_around3000         5518
# parks_around3000         5518
# days_exposition          3181
# kitchen_area             2278
# living_area              1903
# floors_total               86
# locality_name              49
# total_images                0
# last_price                  0
# studio                      0
# floor                       0
# rooms                       0
# first_day_exposition        0
# total_area                  0
# open_plan                   0
# dtype: int64

# %% [markdown]
# Было обнаружено несколько пропусков в следующих столбцах:
# - `ceiling_height`: высота потолков
# - `floors_total`: общее количество этажей
# - `living_area`: жилая площадь
# - `is_apartment`: является ли жилье квартирой
# - `kitchen_area`: площадь кухни
# - `balcony`: кол-во балконов
# - `locality_name`: название населённого пункта
# - `airports_nearest`: расстояние до ближайшего аэропорта
# - `cityCenters_nearest`: расстояние до центра города
# - `parks_around3000`: число парков в радиусе 3 км
# - `parks_nearest`: расстояние до ближайшего парка (м)
# - `ponds_around3000`: число водоёмов в радиусе 3 км
# - `ponds_nearest`: расстояние до ближайшего водоёма (м)
# - `days_exposition`: сколько дней было размещено объявление (от публикации до снятия)

# %% [markdown]
# Теперь взглянем на доли этих пропусков по столбцам, чтобы принять решение об удалении

# %%
df.isna().mean().sort_values(ascending=False) * 100
# Out:
# is_apartment            88.290645
# parks_nearest           65.909954
# ponds_nearest           61.559559
# balcony                 48.605426
# ceiling_height          38.799105
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# ponds_around3000        23.283683
# parks_around3000        23.283683
# days_exposition         13.422507
# kitchen_area             9.612220
# living_area              8.029875
# floors_total             0.362885
# locality_name            0.206760
# total_images             0.000000
# last_price               0.000000
# studio                   0.000000
# floor                    0.000000
# rooms                    0.000000
# first_day_exposition     0.000000
# total_area               0.000000
# open_plan                0.000000
# dtype: float64

# %% [markdown]
# Столбцы `is_apartment`, `parks_nearest`, `ponds_nearest`, `balcony`, `ceiling_height` удалять нецелесообразно, потому что они занимают достаточно большую долю относительно общего числа значений, такие пропуски стоит обработать определенным образом. Например, пропущенные парки и пруды можно заменить нулями, так как скорее всего пропуски подразумевали их отсутствие поблизости.

# %% [markdown]
# ##### Заполнение пропусков в высоте потолка

# %%
df[df['ceiling_height'].isna()].head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 14             1   4400000.0       36.00  2016-06-23T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1              NaN          11.0        18.60      1          NaN  ...
# 2              NaN           5.0        34.30      4          NaN  ...
# 3              NaN          14.0          NaN      9          NaN  ...
# 5              NaN          12.0        14.40      5          NaN  ...
# 6              NaN          26.0        10.60      6          NaN  ...
# 7              NaN          24.0          NaN     22          NaN  ...
# 8              NaN          27.0        15.43     26          NaN  ...
# 11             NaN           5.0        31.00      4        False  ...
# 12             NaN           5.0        30.00      5          NaN  ...
# 14             NaN           6.0        17.00      1          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# 1          11.00      2.0             посёлок Шушары           12817.0
# 2           8.30      0.0            Санкт-Петербург           21741.0
# 3            NaN      0.0            Санкт-Петербург           28098.0
# 5           9.10      NaN  городской посёлок Янино-1               NaN
# 6          14.40      1.0          посёлок Парголово           52996.0
# 7          18.90      2.0            Санкт-Петербург           23982.0
# 8           8.81      NaN             посёлок Мурино               NaN
# 11          6.00      1.0                  Ломоносов           48252.0
# 12          9.00      0.0                  Сертолово               NaN
# 14          8.00      0.0                     Пушкин           20782.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 1              18603.0               0.0            NaN               0.0
# 2              13933.0               1.0           90.0               2.0
# 3               6800.0               2.0           84.0               3.0
# 5                  NaN               NaN            NaN               NaN
# 6              19143.0               0.0            NaN               0.0
# 7              11634.0               0.0            NaN               0.0
# 8                  NaN               NaN            NaN               NaN
# 11             51677.0               0.0            NaN               0.0
# 12                 NaN               NaN            NaN               NaN
# 14             30759.0               0.0            NaN               1.0
#
#     ponds_nearest  days_exposition
# 1             NaN             81.0
# 2           574.0            558.0
# 3           234.0            424.0
# 5             NaN             55.0
# 6             NaN            155.0
# 7             NaN              NaN
# 8             NaN            189.0
# 11            NaN              7.0
# 12            NaN             90.0
# 14           96.0            203.0
#
# [10 rows x 22 columns]

# %% [markdown]
# Скорее всего эти пропуски связаны с тем, что высота потолка неизвестна (т.к. несколько этажей) либо это ошибка системы сбора. Такие значения можно заполнить средним значением высоты потолка по таблицы.

# %%
avg_ceiling_height = math.ceil(df['ceiling_height'].mean() * 100) / 100
df['ceiling_height'] = df['ceiling_height'].fillna(avg_ceiling_height)
display(df['ceiling_height'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### Заполнение пропусков в общем количестве этажей

# %%
df[df['floors_total'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 186              12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237               4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457               4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671               4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757              5   3600000.0        39.0  2017-04-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22542             5   8500000.0        63.5  2017-05-24T00:00:00      2
# 22656             4   4574160.0        64.5  2017-04-02T00:00:00      2
# 22808             0  14569263.0       110.4  2016-11-20T00:00:00      3
# 23590             0  21187872.0       123.3  2017-04-25T00:00:00      3
# 23658             6   3063600.0        43.8  2016-11-28T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 186              2.78           NaN        30.80      4          NaN  ...
# 237              2.78           NaN        20.75      1          NaN  ...
# 457              2.78           NaN        38.40     12          NaN  ...
# 671              2.78           NaN        47.10      8          NaN  ...
# 1757             2.78           NaN          NaN      9          NaN  ...
# ...               ...           ...          ...    ...          ...  ...
# 22542            2.80           NaN          NaN      3          NaN  ...
# 22656            2.78           NaN        31.70     20          NaN  ...
# 22808            2.78           NaN        45.38      6          NaN  ...
# 23590            2.78           NaN        50.40     18          NaN  ...
# 23658            2.70           NaN        14.00      8          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 186           12.00      NaN  Санкт-Петербург           39197.0
# 237             NaN      0.0  Санкт-Петербург           22041.0
# 457           10.63      0.0  Санкт-Петербург           37364.0
# 671           16.80      0.0  Санкт-Петербург           22041.0
# 1757            NaN      0.0  Санкт-Петербург           22735.0
# ...             ...      ...              ...               ...
# 22542           NaN      NaN  Санкт-Петербург           51340.0
# 22656         14.40      0.0  Санкт-Петербург           22041.0
# 22808         23.42      0.0  Санкт-Петербург           19095.0
# 23590         23.60      0.0  Санкт-Петербург           19095.0
# 23658         15.50      2.0  Санкт-Петербург            8426.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 186               12373.0               1.0          123.0               0.0
# 237               17369.0               0.0            NaN               1.0
# 457                8322.0               2.0          309.0               2.0
# 671               17369.0               0.0            NaN               1.0
# 1757              11618.0               1.0          835.0               1.0
# ...                   ...               ...            ...               ...
# 22542             15363.0               0.0            NaN               1.0
# 22656             17369.0               0.0            NaN               1.0
# 22808              4529.0               0.0            NaN               0.0
# 23590              4529.0               0.0            NaN               0.0
# 23658             12082.0               2.0           24.0               1.0
#
#        ponds_nearest  days_exposition
# 186              NaN             49.0
# 237            374.0            251.0
# 457            706.0            727.0
# 671            374.0            123.0
# 1757           652.0             77.0
# ...              ...              ...
# 22542          853.0            512.0
# 22656          374.0            127.0
# 22808            NaN            260.0
# 23590            NaN            104.0
# 23658          271.0            246.0
#
# [86 rows x 22 columns]

# %% [markdown]
# Можно заметить что все квартиры, у которых `floors_total` имеет значение NaN. Такие целосообразней удалить

# %%
df = df.dropna(subset=['floors_total'])
df['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Заполнение пропусков в столбце `is_apartment`

# %%
df[df['is_apartment'].isna() & df['total_area'] < 200]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0                2.70          16.0         51.0      8          NaN  ...
# 1                2.78          11.0         18.6      1          NaN  ...
# 2                2.78           5.0         34.3      4          NaN  ...
# 3                2.78          14.0          NaN      9          NaN  ...
# 4                3.03          14.0         32.0     13          NaN  ...
# ...               ...           ...          ...    ...          ...  ...
# 23694            3.70           5.0         73.3      3          NaN  ...
# 23695            2.78           5.0         38.0      4          NaN  ...
# 23696            2.78           3.0         29.7      1          NaN  ...
# 23697            3.00          17.0          NaN     12          NaN  ...
# 23698            2.50           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 0             25.00      NaN      Санкт-Петербург           18863.0
# 1             11.00      2.0       посёлок Шушары           12817.0
# 2              8.30      0.0      Санкт-Петербург           21741.0
# 3               NaN      0.0      Санкт-Петербург           28098.0
# 4             41.00      NaN      Санкт-Петербург           31856.0
# ...             ...      ...                  ...               ...
# 23694         13.83      NaN      Санкт-Петербург           24665.0
# 23695          8.50      NaN                Тосно               NaN
# 23696           NaN      NaN     село Рождествено               NaN
# 23697         23.30      2.0      Санкт-Петербург           39140.0
# 23698          9.00      NaN  поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                 16028.0               1.0          482.0               2.0
# 1                 18603.0               0.0            NaN               0.0
# 2                 13933.0               1.0           90.0               2.0
# 3                  6800.0               2.0           84.0               3.0
# 4                  8098.0               2.0          112.0               1.0
# ...                   ...               ...            ...               ...
# 23694              4232.0               1.0          796.0               3.0
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23697             10364.0               2.0          173.0               3.0
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 0              755.0              NaN
# 1                NaN             81.0
# 2              574.0            558.0
# 3              234.0            424.0
# 4               48.0            121.0
# ...              ...              ...
# 23694          381.0              NaN
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23697          196.0            602.0
# 23698            NaN              NaN
#
# [23613 rows x 22 columns]

# %% [markdown]
# ##### Заполнение пропусков в жилой площади

# %%
df[df['living_area'].isna()].head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 3               0  64900000.0       159.0  2015-07-24T00:00:00      3
# 7               5   7915000.0        71.6  2019-04-18T00:00:00      2
# 30             12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37             10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44             13   5350000.0        40.0  2018-11-18T00:00:00      1
# 59             15   6300000.0        46.5  2017-03-06T00:00:00      1
# 60              3   2740000.0        35.0  2018-01-01T00:00:00      1
# 81              9  10949000.0        68.0  2018-12-27T00:00:00      1
# 82              3   4500000.0        80.5  2018-01-15T00:00:00      3
# 116            18  10999000.0        97.2  2017-11-13T00:00:00      3
#
#      ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 3              2.78          14.0          NaN      9          NaN  ...
# 7              2.78          24.0          NaN     22          NaN  ...
# 30             2.78           9.0          NaN      2          NaN  ...
# 37             2.50           5.0          NaN      1          NaN  ...
# 44             2.78          22.0          NaN      3          NaN  ...
# 59             2.78          13.0          NaN     13          NaN  ...
# 60             2.78          12.0          NaN      8          NaN  ...
# 81             2.78          10.0          NaN      6          NaN  ...
# 82             2.78          25.0          NaN     16          NaN  ...
# 116            2.50          16.0          NaN     16          NaN  ...
#
#      kitchen_area  balcony                        locality_name  \
# 3             NaN      0.0                      Санкт-Петербург
# 7            18.9      2.0                      Санкт-Петербург
# 30            NaN      NaN                             Коммунар
# 37            NaN      NaN  поселок городского типа Красный Бор
# 44            NaN      1.0                      Санкт-Петербург
# 59            NaN      NaN                      Санкт-Петербург
# 60            NaN      NaN                       посёлок Мурино
# 81            NaN      NaN                      Санкт-Петербург
# 82            NaN      NaN                       посёлок Шушары
# 116          18.3      5.0                      Санкт-Петербург
#
#      airports_nearest cityCenters_nearest  parks_around3000  parks_nearest  \
# 3             28098.0              6800.0               2.0           84.0
# 7             23982.0             11634.0               0.0            NaN
# 30                NaN                 NaN               NaN            NaN
# 37                NaN                 NaN               NaN            NaN
# 44            30471.0             11603.0               1.0          620.0
# 59            11125.0             14501.0               0.0            NaN
# 60                NaN                 NaN               NaN            NaN
# 81                NaN                 NaN               NaN            NaN
# 82            12430.0             18217.0               0.0            NaN
# 116           19426.0             21138.0               0.0            NaN
#
#      ponds_around3000  ponds_nearest  days_exposition
# 3                 3.0          234.0            424.0
# 7                 0.0            NaN              NaN
# 30                NaN            NaN             63.0
# 37                NaN            NaN            196.0
# 44                1.0         1152.0              NaN
# 59                0.0            NaN            336.0
# 60                NaN            NaN             11.0
# 81                NaN            NaN              NaN
# 82                0.0            NaN             60.0
# 116               2.0          390.0            394.0
#
# [10 rows x 22 columns]

# %% [markdown]
# Пропущенная площадь не имеет никакой закономерности. Скорее всего это банальная ошибка в сборе данных, пропуски следует заменить на средние значения по всему датасету

# %%
avg_living_area = math.ceil(df['living_area'].mean() * 100) / 100
df['living_area'] = df['living_area'].fillna(avg_living_area)
display(df['living_area'].isna().sum())
# Out:
# 0

# %% [markdown]
# ##### Заполнение пропусков в колонке балконов

# %%
df[df['balcony'].isna()].head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 16            11   6700000.0       82.00  2017-11-23T00:00:00      3
# 19            16  14200000.0      121.00  2019-01-09T00:00:00      3
# 23            11   2950000.0       32.00  2016-10-29T00:00:00      1
# 26             6   4050000.0       60.00  2017-04-28T00:00:00      4
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0        51.00      8          NaN  ...
# 4             3.03          14.0        32.00     13          NaN  ...
# 5             2.78          12.0        14.40      5          NaN  ...
# 8             2.78          27.0        15.43     26          NaN  ...
# 10            2.67          12.0        20.30      3          NaN  ...
# 16            3.05           5.0        55.60      1          NaN  ...
# 19            2.75          16.0        76.00      8          NaN  ...
# 23            2.60           9.0        17.70      9          NaN  ...
# 26            2.78           5.0        43.00      4          NaN  ...
# 30            2.78           9.0        34.47      2          NaN  ...
#
#     kitchen_area  balcony              locality_name  airports_nearest  \
# 0          25.00      NaN            Санкт-Петербург           18863.0
# 4          41.00      NaN            Санкт-Петербург           31856.0
# 5           9.10      NaN  городской посёлок Янино-1               NaN
# 8           8.81      NaN             посёлок Мурино               NaN
# 10          8.50      NaN            Санкт-Петербург           38357.0
# 16          9.00      NaN            Санкт-Петербург           22108.0
# 19         12.00      NaN            Санкт-Петербург           38900.0
# 23          6.10      NaN            Санкт-Петербург           15414.0
# 26          7.00      NaN            Санкт-Петербург           11580.0
# 30           NaN      NaN                   Коммунар               NaN
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 4               8098.0               2.0          112.0               1.0
# 5                  NaN               NaN            NaN               NaN
# 8                  NaN               NaN            NaN               NaN
# 10             13878.0               1.0          310.0               2.0
# 16             10698.0               3.0          420.0               0.0
# 19             12843.0               0.0            NaN               0.0
# 23             14211.0               2.0          517.0               1.0
# 26             10510.0               0.0            NaN               1.0
# 30                 NaN               NaN            NaN               NaN
#
#     ponds_nearest  days_exposition
# 0           755.0              NaN
# 4            48.0            121.0
# 5             NaN             55.0
# 8             NaN            189.0
# 10          553.0            137.0
# 16            NaN            397.0
# 19            NaN             97.0
# 23          190.0            615.0
# 26           95.0            265.0
# 30            NaN             63.0
#
# [10 rows x 22 columns]

# %% [markdown]
#  Скорее всего балконы являлись опциональным полем ввода и не все люди ввели данные о своих балконах, т.к. посчитали это бесмысленным из-за их отсутствия. Целесообразно заменить эти значения на 0

# %%
df['balcony'] = df['balcony'].fillna(0)
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Заполнение пропусков в колонке площади кухни

# %%
df[df['kitchen_area'].isna()].head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 3               0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30             12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37             10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44             13   5350000.0        40.0  2018-11-18T00:00:00      1
# 59             15   6300000.0        46.5  2017-03-06T00:00:00      1
# 60              3   2740000.0        35.0  2018-01-01T00:00:00      1
# 81              9  10949000.0        68.0  2018-12-27T00:00:00      1
# 82              3   4500000.0        80.5  2018-01-15T00:00:00      3
# 133            12   3150000.0        31.0  2018-03-23T00:00:00      1
# 144             1   2450000.0        27.0  2017-03-30T00:00:00      0
#
#      ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 3              2.78          14.0        34.47      9          NaN  ...
# 30             2.78           9.0        34.47      2          NaN  ...
# 37             2.50           5.0        34.47      1          NaN  ...
# 44             2.78          22.0        34.47      3          NaN  ...
# 59             2.78          13.0        34.47     13          NaN  ...
# 60             2.78          12.0        34.47      8          NaN  ...
# 81             2.78          10.0        34.47      6          NaN  ...
# 82             2.78          25.0        34.47     16          NaN  ...
# 133            2.78          25.0        34.47      6          NaN  ...
# 144            2.78          24.0        15.50      2          NaN  ...
#
#      kitchen_area  balcony                        locality_name  \
# 3             NaN      0.0                      Санкт-Петербург
# 30            NaN      0.0                             Коммунар
# 37            NaN      0.0  поселок городского типа Красный Бор
# 44            NaN      1.0                      Санкт-Петербург
# 59            NaN      0.0                      Санкт-Петербург
# 60            NaN      0.0                       посёлок Мурино
# 81            NaN      0.0                      Санкт-Петербург
# 82            NaN      0.0                       посёлок Шушары
# 133           NaN      0.0                       посёлок Мурино
# 144           NaN      2.0                       посёлок Мурино
#
#      airports_nearest cityCenters_nearest  parks_around3000  parks_nearest  \
# 3             28098.0              6800.0               2.0           84.0
# 30                NaN                 NaN               NaN            NaN
# 37                NaN                 NaN               NaN            NaN
# 44            30471.0             11603.0               1.0          620.0
# 59            11125.0             14501.0               0.0            NaN
# 60                NaN                 NaN               NaN            NaN
# 81                NaN                 NaN               NaN            NaN
# 82            12430.0             18217.0               0.0            NaN
# 133               NaN                 NaN               NaN            NaN
# 144               NaN                 NaN               NaN            NaN
#
#      ponds_around3000  ponds_nearest  days_exposition
# 3                 3.0          234.0            424.0
# 30                NaN            NaN             63.0
# 37                NaN            NaN            196.0
# 44                1.0         1152.0              NaN
# 59                0.0            NaN            336.0
# 60                NaN            NaN             11.0
# 81                NaN            NaN              NaN
# 82                0.0            NaN             60.0
# 133               NaN            NaN             78.0
# 144               NaN            NaN            181.0
#
# [10 rows x 22 columns]

# %% [markdown]
# Скорее всего площадь кухни была пропущенна из-за того что, либо кухня в квартире отсутствует (это объявление на коммунальную квартиру) либо это часть данных не была собрана по какой-то технической причине. Пропущенные значение можно заменить на среднюю площадь кухни

# %%
avg_kitchen_area = math.ceil(df['kitchen_area'].mean() * 10) / 10
df['kitchen_area'] = df['kitchen_area'].fillna(avg_kitchen_area)
display(df['kitchen_area'].isna().sum())
# Out:
# 0

# %% [markdown]
# После заполнения площадей кухни необходимо проверить что столбец общей площади сходится с площадью кухни + жилой площадью

# %%
def kitchen_area_check(row):
    real_total_area = row['total_area']
    living_area = row['living_area']
    kitchen_area = row['kitchen_area']
    tmp_total_area = living_area + kitchen_area
    if tmp_total_area != real_total_area:
        return real_total_area - living_area
    return kitchen_area

df['kitchen_area'] = df.apply(kitchen_area_check, axis=1)

# %% [markdown]
# Теперь заполним пропуски в общей площади

# %%
avg_kitchen_area = math.ceil(df['total_area'].mean() * 10) / 10
df['total_area'] = df['total_area'].fillna(avg_kitchen_area)
display(df['total_area'].isna().sum())
# Out:
# 0

# %%
def total_area_check(row):
    real_total_area = row['total_area']
    living_area = row['living_area']
    kitchen_area = row['kitchen_area']
    tmp_total_area = living_area + kitchen_area
    if tmp_total_area != real_total_area:
        return tmp_total_area
    return real_total_area

df['total_area'] = df.apply(total_area_check, axis=1)

# %% [markdown]
# ##### Заполнение пропусков в колонке населённого пункта

# %%
df[df['locality_name'].isna()].head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1097             3   8600000.0        81.7  2016-04-15T00:00:00      3
# 2033             6   5398000.0        80.0  2017-05-30T00:00:00      3
# 2603            20   3351765.0        42.7  2015-09-20T00:00:00      1
# 2632             2   5130593.0        62.4  2015-10-11T00:00:00      2
# 3574            10   4200000.0        46.5  2016-05-28T00:00:00      2
# 4151            17  17600000.0        89.5  2014-12-09T00:00:00      2
# 4189             7   9200000.0        80.0  2015-12-10T00:00:00      3
# 4670             1   5500000.0        83.0  2015-08-14T00:00:00      3
# 5343            19  13540000.0        85.5  2016-01-20T00:00:00      3
# 5707             7   3700000.0        30.0  2016-04-29T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1097            3.55           5.0        50.80      2          NaN  ...
# 2033            2.78           4.0        42.60      2          NaN  ...
# 2603            2.78          24.0        15.60      3          NaN  ...
# 2632            2.78          24.0        33.10     21          NaN  ...
# 3574            2.78           5.0        30.80      5          NaN  ...
# 4151            3.00           8.0        39.62      7          NaN  ...
# 4189            4.00           4.0        52.30      3        False  ...
# 4670            2.78           7.0        34.47      6          NaN  ...
# 5343            2.78           7.0        59.10      5        False  ...
# 5707            2.78          24.0        20.00     23          NaN  ...
#
#       kitchen_area  balcony  locality_name  airports_nearest  \
# 1097         30.90      0.0            NaN           23478.0
# 2033         37.40      0.0            NaN               NaN
# 2603         27.10      0.0            NaN           22041.0
# 2632         29.30      0.0            NaN           22041.0
# 3574         15.70      0.0            NaN           27419.0
# 4151         49.88      0.0            NaN           25054.0
# 4189         27.70      0.0            NaN           21774.0
# 4670         48.53      0.0            NaN           26534.0
# 5343         26.40      4.0            NaN           10556.0
# 5707         10.00      0.0            NaN           21460.0
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 1097              4258.0               0.0            NaN               0.0
# 2033                 NaN               NaN            NaN               NaN
# 2603             17369.0               0.0            NaN               1.0
# 2632             17369.0               0.0            NaN               1.0
# 3574              8127.0               0.0            NaN               1.0
# 4151              3902.0               1.0          485.0               3.0
# 4189              3039.0               1.0          690.0               1.0
# 4670              5382.0               1.0          446.0               1.0
# 5343              9538.0               1.0           67.0               0.0
# 5707             16788.0               0.0            NaN               1.0
#
#       ponds_nearest  days_exposition
# 1097            NaN            147.0
# 2033            NaN             34.0
# 2603          374.0            276.0
# 2632          374.0            256.0
# 3574          603.0             45.0
# 4151          722.0            869.0
# 4189          953.0            223.0
# 4670          376.0            350.0
# 5343            NaN            303.0
# 5707          170.0             49.0
#
# [10 rows x 22 columns]

# %% [markdown]
# Поскольку анализ ведётся исключительно для Санкт-Петербурга, тяжело сказать к какому населённому пункту относятся эти данные. Логичней было бы их удалить

# %%
df = df.dropna(subset=['locality_name'])
df['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Заполнение пропусков в колонках расстояний

# %%
df['airports_nearest'].isna().sum()
# Out:
# 5524

# %%
df['cityCenters_nearest'].isna().sum()
# Out:
# 5501

# %%
df[df['airports_nearest'].isna()].head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22            20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
# 37            10   1990000.0       45.80  2017-10-28T00:00:00      2
# 38            10   3150000.0       40.00  2018-03-29T00:00:00      1
# 47            17   3600000.0       56.10  2018-10-18T00:00:00      3
# 60             3   2740000.0       35.00  2018-01-01T00:00:00      1
# 62             0   4800000.0       78.60  2017-09-17T00:00:00      3
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 5             2.78          12.0        14.40      5          NaN  ...
# 8             2.78          27.0        15.43     26          NaN  ...
# 12            2.78           5.0        30.00      5          NaN  ...
# 22            2.75          25.0        30.00     15          NaN  ...
# 30            2.78           9.0        34.47      2          NaN  ...
# 37            2.50           5.0        34.47      1          NaN  ...
# 38            2.75          18.0        16.30      9          NaN  ...
# 47            2.78           4.0        42.50      3          NaN  ...
# 60            2.78          12.0        34.47      8          NaN  ...
# 62            2.80           9.0        48.80      5          NaN  ...
#
#     kitchen_area  balcony                        locality_name  \
# 5          16.00      0.0            городской посёлок Янино-1
# 8          17.73      0.0                       посёлок Мурино
# 12         24.00      0.0                            Сертолово
# 22         28.00      2.0                      деревня Кудрово
# 30         -1.67      0.0                             Коммунар
# 37         11.33      0.0  поселок городского типа Красный Бор
# 38         23.70      0.0                       посёлок Мурино
# 47         13.60      1.0                              Гатчина
# 60          0.53      0.0                       посёлок Мурино
# 62         29.80      2.0                            Сертолово
#
#     airports_nearest cityCenters_nearest  parks_around3000  parks_nearest  \
# 5                NaN                 NaN               NaN            NaN
# 8                NaN                 NaN               NaN            NaN
# 12               NaN                 NaN               NaN            NaN
# 22               NaN                 NaN               NaN            NaN
# 30               NaN                 NaN               NaN            NaN
# 37               NaN                 NaN               NaN            NaN
# 38               NaN                 NaN               NaN            NaN
# 47               NaN                 NaN               NaN            NaN
# 60               NaN                 NaN               NaN            NaN
# 62               NaN                 NaN               NaN            NaN
#
#     ponds_around3000  ponds_nearest  days_exposition
# 5                NaN            NaN             55.0
# 8                NaN            NaN            189.0
# 12               NaN            NaN             90.0
# 22               NaN            NaN             60.0
# 30               NaN            NaN             63.0
# 37               NaN            NaN            196.0
# 38               NaN            NaN            103.0
# 47               NaN            NaN            179.0
# 60               NaN            NaN             11.0
# 62               NaN            NaN              5.0
#
# [10 rows x 22 columns]

# %% [markdown]
# Внушительное количество пропущенных данных по аэропортам. Возможно так показаны квартиры, которые находятся слишком далеко от основного аэропорта (Пулково). Например, Сертолово находится настолько далеко от аэропорта, что записывать расстояние заполняющий/система не посчитала нужным. Так же можно заметить что почти все данные, в которых отсутствует расстояние до аэропорта имеют пропуски почти по всех колонках с расстоянием до чего либо. В таких квартирах пропущена почти половина необходимых данных и делать какие-то логичные выводы будет очень тяжело. Удаляем :)

# %%
df = df.dropna(subset=['airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest'])
df['airports_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### Заполнение пропусков в колонках размещения по дням

# %%
df[df['days_exposition'].isna()].head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 0              20  13000000.0       108.0  2019-03-07T00:00:00      3
# 44             13   5350000.0        40.0  2018-11-18T00:00:00      1
# 71             20   4850000.0        57.5  2019-03-27T00:00:00      3
# 114             5   4000000.0        21.4  2019-02-07T00:00:00      1
# 126            10   4050000.0        51.0  2019-04-23T00:00:00      2
# 206            16   5080000.0        31.3  2019-04-23T00:00:00      1
# 207            11   9000000.0        72.6  2018-09-08T00:00:00      2
# 233            17  19800000.0       118.0  2017-12-15T00:00:00      3
# 270            13   3700000.0        34.0  2019-03-18T00:00:00      1
# 278            19   6000000.0        56.7  2019-03-11T00:00:00      2
#
#      ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0              2.70          16.0        51.00      8          NaN  ...
# 44             2.78          22.0        34.47      3          NaN  ...
# 71             2.50           9.0        39.00      8          NaN  ...
# 114            2.90           8.0         8.30      7          NaN  ...
# 126            2.78           5.0        30.50      1          NaN  ...
# 206            2.50           7.0        16.00      4        False  ...
# 207            2.90           5.0        43.20      4          NaN  ...
# 233            2.80          25.0        62.00      3          NaN  ...
# 270            2.60          10.0        18.00      8          NaN  ...
# 278            3.20           5.0        34.10      5          NaN  ...
#
#      kitchen_area  balcony    locality_name  airports_nearest  \
# 0           57.00      0.0  Санкт-Петербург           18863.0
# 44           5.53      1.0  Санкт-Петербург           30471.0
# 71          18.50      0.0  Санкт-Петербург           33623.0
# 114         13.10      0.0  Санкт-Петербург           27089.0
# 126         20.50      0.0           Пушкин           17974.0
# 206         15.30      1.0  Санкт-Петербург           27753.0
# 207         29.40      0.0  Санкт-Петербург           22794.0
# 233         56.00      0.0  Санкт-Петербург           36827.0
# 270         16.00      1.0  Санкт-Петербург           32831.0
# 278         22.60      0.0  Санкт-Петербург           22800.0
#
#     cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0               16028.0               1.0          482.0               2.0
# 44              11603.0               1.0          620.0               1.0
# 71              12267.0               1.0          334.0               1.0
# 114              5791.0               2.0          488.0               1.0
# 126             32546.0               1.0           15.0               1.0
# 206              6692.0               1.0          860.0               1.0
# 207              1645.0               2.0          276.0               3.0
# 233             12348.0               1.0          485.0               1.0
# 270             13995.0               1.0          104.0               1.0
# 278              9274.0               1.0           77.0               1.0
#
#      ponds_nearest  days_exposition
# 0            755.0              NaN
# 44          1152.0              NaN
# 71           333.0              NaN
# 114          286.0              NaN
# 126          659.0              NaN
# 206          694.0              NaN
# 207          485.0              NaN
# 233          474.0              NaN
# 270          393.0              NaN
# 278          542.0              NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# Скоре всего данные квартиры не выставлены на продажу так как они еще не проданы. В таком случае их не следует удалять

# %% [markdown]
# #### Типа данных в таблице

# %%
df.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment             object
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# cityCenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %%
df.head(5)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0       108.0  2019-03-07T00:00:00      3
# 2             10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4              2  10000000.0       100.0  2018-06-19T00:00:00      2
# 10             5   5050000.0        39.6  2017-11-16T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             2.70          16.0        51.00      8          NaN  ...
# 2             2.78           5.0        34.30      4          NaN  ...
# 3             2.78          14.0        34.47      9          NaN  ...
# 4             3.03          14.0        32.00     13          NaN  ...
# 10            2.67          12.0        20.30      3          NaN  ...
#
#     kitchen_area  balcony    locality_name  airports_nearest  \
# 0          57.00      0.0  Санкт-Петербург           18863.0
# 2          21.70      0.0  Санкт-Петербург           21741.0
# 3         124.53      0.0  Санкт-Петербург           28098.0
# 4          68.00      0.0  Санкт-Петербург           31856.0
# 10         19.30      0.0  Санкт-Петербург           38357.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.0               1.0          482.0               2.0
# 2              13933.0               1.0           90.0               2.0
# 3               6800.0               2.0           84.0               3.0
# 4               8098.0               2.0          112.0               1.0
# 10             13878.0               1.0          310.0               2.0
#
#     ponds_nearest  days_exposition
# 0           755.0              NaN
# 2           574.0            558.0
# 3           234.0            424.0
# 4            48.0            121.0
# 10          553.0            137.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Сразу в глаза бросается паттерн, где значения, которые не могут быть вещественными, имеют тип `float64`. Таким значениям следует изменить тип на `int64`. Речь идет о следующих столбцах:
# - `floors_total`
# - `balcony`
# - `parks_around3000`
# - `ponds_around3000`

# %% [markdown]
# Для начала убедимся, что колонки не имеют значений с вещественной частью

# %%
def check_float(df, column_name):
    return df[df[column_name] % 1 != 0][column_name].sum()

for column in ['floors_total', 'balcony', 'parks_around3000', 'ponds_around3000']:
    if check_float(df, column) > 0:
        display(f'{column} has float')
    else:
        display(f'{column} is OK')
# Out:
# 'floors_total is OK'
# 'balcony is OK'
# 'parks_around3000 is OK'
# 'ponds_around3000 is OK'

# %% [markdown]
# Теперь заменим типы этих колонок

# %%
df['floors_total'] = df['floors_total'].astype(int)
df['balcony'] = df['balcony'].astype(int)
df['parks_around3000'] = df['parks_around3000'].astype(int)
df['ponds_around3000'] = df['ponds_around3000'].astype(int)

# %% [markdown]
# Теперь проверив неочевидные колонки:
# - `airports_nearest`
# - `cityCenters_nearest`
# - `parks_nearest`
# - `ponds_nearest`

# %%
for column in ['last_price', 'airports_nearest', 'cityCenters_nearest', 'parks_nearest', 'ponds_nearest']:
    if check_float(df, column) > 0:
        display(f'{column} has float')
    else:
        display(f'{column} is OK')
# Out:
# 'last_price is OK'
# 'airports_nearest is OK'
# 'cityCenters_nearest is OK'
# 'parks_nearest is OK'
# 'ponds_nearest is OK'

# %% [markdown]
# Как мы видим, все значения в расстояниях имеют целые числа, поэтому логичнее заменить их на тип `int`

# %%
df['last_price'] = df['last_price'].astype(int)
df['airports_nearest'] = df['airports_nearest'].astype(int)
df['cityCenters_nearest'] = df['cityCenters_nearest'].astype(int)
df['parks_nearest'] = df['parks_nearest'].astype(int)
df['ponds_nearest'] = df['ponds_nearest'].astype(int)

# %% [markdown]
# Также некоторые столбцы можно перевести из `object` во что-то иное, более подходящее. `locality_name` можно сделать `str`, а `is_apartment` - в `bool`

# %%
df['locality_name'] = df['locality_name'].astype("string")
df['is_apartment'] = df['is_apartment'].astype(bool)

# %% [markdown]
# Взглянем на новые типы

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition            object
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name           string[python]
# airports_nearest                 int64
# cityCenters_nearest              int64
# parks_around3000                 int64
# parks_nearest                    int64
# ponds_around3000                 int64
# ponds_nearest                    int64
# days_exposition                float64
# dtype: object

# %% [markdown]
# #### Устраняем неявные дубликаты

# %%
df['locality_name'].unique()
# Out:
# <StringArray>
# [  'Санкт-Петербург',          'Петергоф',            'Пушкин',
#          'Кронштадт',           'Колпино',          'Павловск',
#         'Сестрорецк',       'Зеленогорск',         'Ломоносов',
#  'посёлок Парголово',      'Красное Село',  'посёлок Стрельна']
# Length: 12, dtype: string

# %% [markdown]
# В названиях не обнаружено неявных дубликатов

# %% [markdown]
# ### Добавим новые столбцы

# %% [markdown]
# Добавим столбцы со следующими параметрами:
# - цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).

# %%
from datetime import datetime

def process_day(row):
    date = row['first_day_exposition']
    date_obj = datetime.fromisoformat(date.split('T')[0])
    return date_obj.weekday()

def process_month(row):
    date = row['first_day_exposition']
    return date.split('-')[1]

def process_year(row):
    date = row['first_day_exposition']
    return date.split('-')[0]
    

def assign_floot_type(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    return 'другой'

df['price_per_sqm'] = (df['last_price'] / df['total_area']).round(2)
df['day_of_the_week'] = df.apply(process_day, axis=1)
df['month_exposition'] = df.apply(process_month, axis=1).astype(int)
df['year_exposition'] = df.apply(process_year, axis=1).astype(int)
df['floor_type'] = df.apply(assign_floot_type, axis=1)
df['cityCenters_nearest_km'] = round(df['cityCenters_nearest'] / 1000)

# %%
df.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000       108.0  2019-03-07T00:00:00      3
# 2             10     5196000        56.0  2015-08-20T00:00:00      2
# 3              0    64900000       159.0  2015-07-24T00:00:00      3
# 4              2    10000000       100.0  2018-06-19T00:00:00      2
# 10             5     5050000        39.6  2017-11-16T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70            16        51.00      8          True  ...
# 2             2.78             5        34.30      4          True  ...
# 3             2.78            14        34.47      9          True  ...
# 4             3.03            14        32.00     13          True  ...
# 10            2.67            12        20.30      3          True  ...
#
#     parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 0             482                 2            755              NaN
# 2              90                 2            574            558.0
# 3              84                 3            234            424.0
# 4             112                 1             48            121.0
# 10            310                 2            553            137.0
#
#    price_per_sqm  day_of_the_week  month_exposition  year_exposition  \
# 0      120370.37                3                 3             2019
# 2       92785.71                3                 8             2015
# 3      408176.10                4                 7             2015
# 4      100000.00                1                 6             2018
# 10     127525.25                3                11             2017
#
#     floor_type  cityCenters_nearest_km
# 0       другой                    16.0
# 2       другой                    14.0
# 3       другой                     7.0
# 4       другой                     8.0
# 10      другой                    14.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Изучим гистограммы для некоторых числовых параметров

# %% [markdown]
# Для начала построим гистограмму для общей площади

# %%
plt.hist(df['total_area'], linewidth=1, edgecolor='black')
plt.xlabel('Площадь квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение площадей квартир')
plt.grid(True)
plt.show()

# %% [markdown]
# Из гистограммы видно что большая часть квартир приходиться на квартиры, которые меньше 100 кв/м

# %%
plt.hist(df['rooms'], linewidth=1, edgecolor='black')
plt.xlabel('Площадь квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение площадей квартир')
plt.grid(True)
plt.show()

# %% [markdown]
# Большая часть квартир имеет до 4 комнат

# %%
plt.hist(df['kitchen_area'], linewidth=1, edgecolor='black')
plt.xlabel('Площадь кухни')
plt.ylabel('Количество кухонь')
plt.title('Распределение площадей кухонь')
plt.grid(True)
plt.show()

# %% [markdown]
# Площадь кухни обычно не превышает 10-20 квардатных метров

# %%
plt.hist(df['floors_total'], linewidth=1, edgecolor='black')
plt.xlabel('Количествой этажей')
plt.ylabel('Количество квартир')
plt.title('Распределение количества этажей')
plt.grid(True)
plt.show()

# %% [markdown]
# Сравнив графики общей площади, жилой площади, площади кухни, количества комнат и этажей, можно заметить, что они имеют примерно похожие распределения, что логично. Чем больше общая площадь недвижимости, тем больше жилая площадь, кухня и количество комнат.

# %%
plt.hist(df['ceiling_height'], linewidth=1, edgecolor='black')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.title('Распределение высоты потолков')
plt.grid(True)
plt.show()

# %% [markdown]
# Из гистограммы видно что в столбце присутствуют аномальные значения высоты потолков, которые необходимо обработать

# %%
df.query('ceiling_height > 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 464              15    66571000       280.3  2015-06-11T00:00:00      6
# 1388             20    59800000       399.0  2015-01-21T00:00:00      5
# 4643              0     4300000        45.0  2018-02-01T00:00:00      2
# 5076              0     3850000        30.5  2018-10-03T00:00:00      1
# 6246              6     3300000        44.4  2019-03-25T00:00:00      2
# 12628            14     3900000        50.0  2018-03-29T00:00:00      1
# 20264            17   119000000       187.6  2017-07-10T00:00:00      4
# 21227             0     8200000        71.0  2017-07-21T00:00:00      0
# 22309            20     5300000        45.0  2017-09-30T00:00:00      1
# 22869             0    15000000        25.0  2018-07-25T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 464               5.2             8       159.50      7          True  ...
# 1388              5.6             6        34.47      6          True  ...
# 4643             25.0             9        30.00      2          True  ...
# 5076             24.0             5        19.50      1          True  ...
# 6246             25.0             5        31.30      5          True  ...
# 12628             5.3             5        34.47      5          True  ...
# 20264             6.0             7       147.00      7          True  ...
# 21227             5.8             5        68.00      5          True  ...
# 22309            10.3            16        15.50     15          True  ...
# 22869           100.0             5        14.00      5          True  ...
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 464              187                 1            616            578.0
# 1388             149                 2            577            719.0
# 4643             658                 1            331            181.0
# 5076             397                 1            578              7.0
# 6246             417                 2             73              NaN
# 12628            505                 1             92              8.0
# 20264            484                 1            305            259.0
# 21227            295                 3            366             30.0
# 22309            440                 2            450            136.0
# 22869            223                 3             30             19.0
#
#       price_per_sqm  day_of_the_week  month_exposition  year_exposition  \
# 464       237499.11                3                 6             2015
# 1388      149874.69                2                 1             2015
# 4643       95555.56                3                 2             2018
# 5076      126229.51                2                10             2018
# 6246       74324.32                0                 3             2019
# 12628      78000.00                3                 3             2018
# 20264     634328.36                0                 7             2017
# 21227     115492.96                4                 7             2017
# 22309     117777.78                5                 9             2017
# 22869     600000.00                2                 7             2018
#
#        floor_type  cityCenters_nearest_km
# 464        другой                     7.0
# 1388    последний                     7.0
# 4643       другой                    13.0
# 5076       первый                     8.0
# 6246    последний                    51.0
# 12628   последний                     4.0
# 20264   последний                     6.0
# 21227   последний                     1.0
# 22309      другой                    12.0
# 22869   последний                     8.0
#
# [10 rows x 28 columns]

# %% [markdown]
# В первом случае, скорее всего имелась ввиду высота в 2.4 метра, а вот второй случай мало понятен, ведь при площади в 25 кв/м и цене в 15_000_000 тяжело представить себе такую недвижимость, поэтому логичнее удалиться это значение

# %%
df.loc[df['ceiling_height'] == 24, 'ceiling_height'] = 2.4
df = df.query('ceiling_height != 100.0')
plt.hist(df['ceiling_height'], linewidth=1, edgecolor='black')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.title('Распределение высоты потолков')
plt.show()

# %% [markdown]
# Теперь аномалий нет, большая часть квартир имеет высоту в 2.75м

# %%
df['floor_type'].value_counts().plot(kind='bar', linewidth=1, edgecolor='black')
# Out:
# <Axes: xlabel='floor_type'>

# %% [markdown]
# Большая часть квартир находится между первым и последним этажами, что логично для многоэтажных домов

# %%
plt.hist(df['cityCenters_nearest_km'], bins=20, linewidth=1, edgecolor='black')
plt.xlabel('Расстояние до центра (км)')
plt.ylabel('Количество квартир')
plt.title('Распределение расстояние до центра')
plt.show()

# %%
plt.hist(df['parks_nearest'], linewidth=1, edgecolor='black')
plt.xlabel('Расстояние до центра')
plt.ylabel('Количество квартир')
plt.title('Распределение расстояние до центра')
plt.show()

# %% [markdown]
# Гистограммы для этих двух столбцов похожи. Дома которые выпадают из общего числа скорее всего находятся загородом и находятся равноудаленно от центра города и парков

# %% [markdown]
# #### Изучим скорость продажи квартир

# %%
plt.hist(df['days_exposition'], linewidth=1, edgecolor='black')
plt.xlabel('Возраст объявления')
plt.ylabel('Количество квартир')
plt.title('Распределение возраста объявлений')
plt.show()

# %% [markdown]
# Гистограмма соответствуют распределению Пуассона которое характерно для значений связанных со временем. Взглянем на среднее арифметическое и медианное значения

# %%
df.boxplot(column=['days_exposition'])
df['days_exposition'].describe()
# Out:
# count    4082.000000
# mean      203.546546
# std       242.513736
# min         1.000000
# 25%        45.000000
# 50%       110.500000
# 75%       264.750000
# max      1572.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Исходя из значений квартилей можно сказать, что квартиры которые проданых в диапазоне от 56 до 224 дней являются нормальными продажами. Если квартиры была продана меньше чем за 56 дней, то это быстрая продажа, а если больше чем за 224 дня - долгая

# %% [markdown]
# #### Определим от чего зависит стоимость объекта

# %% [markdown]
# Чтобы определить есть ли завимисость между ценой и различными посмотрим на их коэфициенты корреляции.

# %%
for column in ['total_area', 'living_area', 'kitchen_area', 'rooms',
               'day_of_the_week', 'month_exposition', 'year_exposition']:
    print(f'Correlation between "last_price" and "{column}" is {df["last_price"].corr(df[column])}')
# Out:
# Correlation between "last_price" and "total_area" is 0.5920790302217763
# Correlation between "last_price" and "living_area" is 0.5095878091714837
# Correlation between "last_price" and "kitchen_area" is 0.5336762774806845
# Correlation between "last_price" and "rooms" is 0.34559093558979853
# Correlation between "last_price" and "day_of_the_week" is 0.015593934297074754
# Correlation between "last_price" and "month_exposition" is -0.00510566945440283
# Correlation between "last_price" and "year_exposition" is -0.06470445125433007

# %% [markdown]
# Видно, что есть небольшая зависимость связанная с размером кухни и кол-вом комнат и чуть большая зависимость связанная с жилой площадью и общей площадью. С датами же цена особо не связана

# %% [markdown]
# Чтобы выяснить от чего зависит цена проанализируем следующие столбцы и построим матрицу диаграм рассеяния:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - количество комнат;
# - тип этажа, на котором расположена квартира (первый, последний, другой);
# - дата размещения

# %%
df['floor_type_numeric'] = df['floor_type'].astype('category').cat.codes

relevant_columns = df[['total_area', 'living_area', 'kitchen_area', 'rooms', 'floor_type_numeric', 'last_price', 'days_exposition', 'day_of_the_week', 'month_exposition', 'year_exposition']]

pd.plotting.scatter_matrix(relevant_columns, figsize=(15, 15))
# Out:
# array([[<Axes: xlabel='total_area', ylabel='total_area'>,
#         <Axes: xlabel='living_area', ylabel='total_area'>,
#         <Axes: xlabel='kitchen_area', ylabel='total_area'>,
#         <Axes: xlabel='rooms', ylabel='total_area'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='total_area'>,
#         <Axes: xlabel='last_price', ylabel='total_area'>,
#         <Axes: xlabel='days_exposition', ylabel='total_area'>,
#         <Axes: xlabel='day_of_the_week', ylabel='total_area'>,
#         <Axes: xlabel='month_exposition', ylabel='total_area'>,
#         <Axes: xlabel='year_exposition', ylabel='total_area'>],
#        [<Axes: xlabel='total_area', ylabel='living_area'>,
#         <Axes: xlabel='living_area', ylabel='living_area'>,
#         <Axes: xlabel='kitchen_area', ylabel='living_area'>,
#         <Axes: xlabel='rooms', ylabel='living_area'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='living_area'>,
#         <Axes: xlabel='last_price', ylabel='living_area'>,
#         <Axes: xlabel='days_exposition', ylabel='living_area'>,
#         <Axes: xlabel='day_of_the_week', ylabel='living_area'>,
#         <Axes: xlabel='month_exposition', ylabel='living_area'>,
#         <Axes: xlabel='year_exposition', ylabel='living_area'>],
#        [<Axes: xlabel='total_area', ylabel='kitchen_area'>,
#         <Axes: xlabel='living_area', ylabel='kitchen_area'>,
#         <Axes: xlabel='kitchen_area', ylabel='kitchen_area'>,
#         <Axes: xlabel='rooms', ylabel='kitchen_area'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='kitchen_area'>,
#         <Axes: xlabel='last_price', ylabel='kitchen_area'>,
#         <Axes: xlabel='days_exposition', ylabel='kitchen_area'>,
#         <Axes: xlabel='day_of_the_week', ylabel='kitchen_area'>,
#         <Axes: xlabel='month_exposition', ylabel='kitchen_area'>,
#         <Axes: xlabel='year_exposition', ylabel='kitchen_area'>],
#        [<Axes: xlabel='total_area', ylabel='rooms'>,
#         <Axes: xlabel='living_area', ylabel='rooms'>,
#         <Axes: xlabel='kitchen_area', ylabel='rooms'>,
#         <Axes: xlabel='rooms', ylabel='rooms'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='rooms'>,
#         <Axes: xlabel='last_price', ylabel='rooms'>,
#         <Axes: xlabel='days_exposition', ylabel='rooms'>,
#         <Axes: xlabel='day_of_the_week', ylabel='rooms'>,
#         <Axes: xlabel='month_exposition', ylabel='rooms'>,
#         <Axes: xlabel='year_exposition', ylabel='rooms'>],
#        [<Axes: xlabel='total_area', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='living_area', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='kitchen_area', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='rooms', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='last_price', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='days_exposition', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='day_of_the_week', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='month_exposition', ylabel='floor_type_numeric'>,
#         <Axes: xlabel='year_exposition', ylabel='floor_type_numeric'>],
#        [<Axes: xlabel='total_area', ylabel='last_price'>,
#         <Axes: xlabel='living_area', ylabel='last_price'>,
#         <Axes: xlabel='kitchen_area', ylabel='last_price'>,
#         <Axes: xlabel='rooms', ylabel='last_price'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='last_price'>,
#         <Axes: xlabel='last_price', ylabel='last_price'>,
#         <Axes: xlabel='days_exposition', ylabel='last_price'>,
#         <Axes: xlabel='day_of_the_week', ylabel='last_price'>,
#         <Axes: xlabel='month_exposition', ylabel='last_price'>,
#         <Axes: xlabel='year_exposition', ylabel='last_price'>],
#        [<Axes: xlabel='total_area', ylabel='days_exposition'>,
#         <Axes: xlabel='living_area', ylabel='days_exposition'>,
#         <Axes: xlabel='kitchen_area', ylabel='days_exposition'>,
#         <Axes: xlabel='rooms', ylabel='days_exposition'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='days_exposition'>,
#         <Axes: xlabel='last_price', ylabel='days_exposition'>,
#         <Axes: xlabel='days_exposition', ylabel='days_exposition'>,
#         <Axes: xlabel='day_of_the_week', ylabel='days_exposition'>,
#         <Axes: xlabel='month_exposition', ylabel='days_exposition'>,
#         <Axes: xlabel='year_exposition', ylabel='days_exposition'>],
#        [<Axes: xlabel='total_area', ylabel='day_of_the_week'>,
#         <Axes: xlabel='living_area', ylabel='day_of_the_week'>,
#         <Axes: xlabel='kitchen_area', ylabel='day_of_the_week'>,
#         <Axes: xlabel='rooms', ylabel='day_of_the_week'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='day_of_the_week'>,
#         <Axes: xlabel='last_price', ylabel='day_of_the_week'>,
#         <Axes: xlabel='days_exposition', ylabel='day_of_the_week'>,
#         <Axes: xlabel='day_of_the_week', ylabel='day_of_the_week'>,
#         <Axes: xlabel='month_exposition', ylabel='day_of_the_week'>,
#         <Axes: xlabel='year_exposition', ylabel='day_of_the_week'>],
#        [<Axes: xlabel='total_area', ylabel='month_exposition'>,
#         <Axes: xlabel='living_area', ylabel='month_exposition'>,
#         <Axes: xlabel='kitchen_area', ylabel='month_exposition'>,
#         <Axes: xlabel='rooms', ylabel='month_exposition'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='month_exposition'>,
#         <Axes: xlabel='last_price', ylabel='month_exposition'>,
#         <Axes: xlabel='days_exposition', ylabel='month_exposition'>,
#         <Axes: xlabel='day_of_the_week', ylabel='month_exposition'>,
#         <Axes: xlabel='month_exposition', ylabel='month_exposition'>,
#         <Axes: xlabel='year_exposition', ylabel='month_exposition'>],
#        [<Axes: xlabel='total_area', ylabel='year_exposition'>,
#         <Axes: xlabel='living_area', ylabel='year_exposition'>,
#         <Axes: xlabel='kitchen_area', ylabel='year_exposition'>,
#         <Axes: xlabel='rooms', ylabel='year_exposition'>,
#         <Axes: xlabel='floor_type_numeric', ylabel='year_exposition'>,
#         <Axes: xlabel='last_price', ylabel='year_exposition'>,
#         <Axes: xlabel='days_exposition', ylabel='year_exposition'>,
#         <Axes: xlabel='day_of_the_week', ylabel='year_exposition'>,
#         <Axes: xlabel='month_exposition', ylabel='year_exposition'>,
#         <Axes: xlabel='year_exposition', ylabel='year_exposition'>]],
#       dtype=object)

# %% [markdown]
# Можно увидеть, что общая площадь, площадь кухни и жилая площадь влияют на цену недвижимости. Зависимость тут прямая - большая площадь как правило ведет к более высокой цене. То же самое касается и количества комнат. Квартиры расположенные на первом этаже как правило имеют более низкую цену, а относительно недавно размещенные как правило имеют чуть более высокую цену. День недели и месяц не особо влияют на цену, а вот более поздние года имеют немного выросшие цены на недвижимость.

# %% [markdown]
# #### Определим стоимость в зависимости от населённого пункта

# %%
pivot = df.pivot_table(index = 'locality_name', values = 'price_per_sqm', aggfunc = ['count', 'mean'])
pivot.columns = ['count', 'price_per_sqm']
(
    pivot.sort_values(by = 'count', ascending = False).head(10)
    .sort_values(by='price_per_sqm', ascending = False)
)
# Out:
#                   count  price_per_sqm
# locality_name
# Санкт-Петербург    4228  128739.720220
# Зеленогорск          16  109891.073125
# Сестрорецк           72  108831.614583
# Пушкин              133  107265.692782
# Павловск             24   90949.239583
# посёлок Стрельна     17   88558.942353
# Петергоф            111   86604.563063
# Кронштадт            81   79568.634938
# Колпино              68   77017.248235
# Ломоносов            14   67878.869286

# %% [markdown]
# Как можно увидеть, самая большая цена в Санкт-Петербурге, а меньшая в Ломоносове. Скорее всего цены в Ломоносове можно объяснить удаленностью от большинства ценоопределяющих локаций

# %% [markdown]
# #### Определим стоимость в зависимости от удалённости от центра

# %%
pivot_table = (
    df[df['locality_name'] == 'Санкт-Петербург']
    .pivot_table(index='locality_name', values='price_per_sqm', columns='cityCenters_nearest_km', aggfunc='mean')
)
sorted_pivot_table = pivot_table.sort_values(by=pivot_table.columns[0], ascending=False)
sorted_pivot_table.T.plot(kind='line', marker='o')
plt.ylabel('Средняя цена за кв/м')
plt.title('Средняя цена за расстояние')
plt.show()

# %% [markdown]
# Как видно удалённость от центра так же влияет на цену за недвижимость. Чем дальше от центра, тем дешевле

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Проведя подробный анализ можно сказать, что на цену квартиры влияют несколько факторов. Больше всего влияет общая и жилая площади квартиры, чуть меньше площадь кухни и количество комнат. День недели, месяц особо не играют роли, но недавно размещенные квартиры, а так же более поздние года размещения имеют тенденцию иметь чуть более высокие цены. Квартиры расположенные на первом этаже продаются дешевле чем квартиры на других этажах. Расстояние до Аэропорта и Центра так же важно. Чем ближе, тем дороже. То же самое касается и насённого пункта, его близость к ключевым ценоопределяющим точка важна. Сам Санкт-Петербург имеет наибольшие цены за недвижимость тогда как Ломоносов - наименьшее. Санкт-Петербург так же лидирует по количеству объявлений, а Ломоносов имеет их меньше всего.
