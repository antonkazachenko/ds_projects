# %% [markdown]
# # 0. Install and import the libraries

# %%
# !pip install numpy
# !pip install tensorflow
# !pip install keras
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in f:\coding\ds_projects\venv\lib\site-packages (1.21.6)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-win_amd64.whl.metadata (2.5 kB)
# Collecting tensorflow-intel==2.11.0 (from tensorflow)
#   Downloading tensorflow_intel-2.11.0-cp37-cp37m-win_amd64.whl.metadata (3.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=2.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading h5py-3.8.0-cp37-cp37m-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.20 in f:\coding\ds_projects\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in f:\coding\ds_projects\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading protobuf-3.19.6-cp37-cp37m-win_amd64.whl.metadata (807 bytes)
# Requirement already satisfied: setuptools in f:\coding\ds_projects\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in f:\coding\ds_projects\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading termcolor-2.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in f:\coding\ds_projects\venv\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading wrapt-1.16.0-cp37-cp37m-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading grpcio-1.62.3-cp37-cp37m-win_amd64.whl.metadata (4.2 kB)
# Collecting tensorboard<2.12,>=2.11 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading tensorboard-2.11.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.12,>=2.11.0 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading keras-2.11.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.11.0->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp37-cp37m-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in f:\coding\ds_projects\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.42.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading Markdown-3.4.4-py3-none-any.whl.metadata (6.9 kB)
# Collecting requests<3,>=2.21.0 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl.metadata (873 bytes)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in f:\coding\ds_projects\venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading charset_normalizer-3.4.0-cp37-cp37m-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: idna<4,>=2.5 in f:\coding\ds_projects\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.10)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in f:\coding\ds_projects\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in f:\coding\ds_projects\venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.11.0-cp37-cp37m-win_amd64.whl (1.9 kB)
# Downloading tensorflow_intel-2.11.0-cp37-cp37m-win_amd64.whl (266.3 MB)
#    ---------------------------------------- 266.3/266.3 MB 3.3 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ---------------------------------------- 133.7/133.7 kB 4.0 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Downloading grpcio-1.62.3-cp37-cp37m-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 4.5/4.5 MB 6.2 MB/s eta 0:00:00
# Downloading h5py-3.8.0-cp37-cp37m-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 2.6/2.6 MB 3.4 MB/s eta 0:00:00
# Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 1.7/1.7 MB 5.1 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 26.4/26.4 MB 3.7 MB/s eta 0:00:00
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 65.5/65.5 kB 3.7 MB/s eta 0:00:00
# Downloading protobuf-3.19.6-cp37-cp37m-win_amd64.whl (896 kB)
#    ---------------------------------------- 896.6/896.6 kB 5.2 MB/s eta 0:00:00
# Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#    ---------------------------------------- 6.0/6.0 MB 3.9 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#    ---------------------------------------- 439.2/439.2 kB 3.9 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp37-cp37m-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 4.3 MB/s eta 0:00:00
# Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Downloading wrapt-1.16.0-cp37-cp37m-win_amd64.whl (37 kB)
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
#    --------------------------------------- 209.5/209.5 kB 13.3 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Downloading Markdown-3.4.4-py3-none-any.whl (94 kB)
#    ---------------------------------------- 94.2/94.2 kB 5.2 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#    ---------------------------------------- 781.3/781.3 kB 8.2 MB/s eta 0:00:00
# Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#    ---------------------------------------- 233.6/233.6 kB 2.9 MB/s eta 0:00:00
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ---------------------------------------- 167.3/167.3 kB 9.8 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.0-cp37-cp37m-win_amd64.whl (99 kB)
#    ---------------------------------------- 99.9/99.9 kB 5.6 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#    --------------------------------------- 181.3/181.3 kB 10.7 MB/s eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ---------------------------------------- 124.2/124.2 kB ? eta 0:00:00
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 151.7/151.7 kB 9.4 MB/s eta 0:00:00
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ---------------------------------------- 84.9/84.9 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, wrapt, werkzeug, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, keras, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, astunparse, absl-py, rsa, requests, pyasn1-modules, markdown, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 cachetools-5.5.0 certifi-2024.8.30 charset-normalizer-3.4.0 flatbuffers-24.3.25 gast-0.4.0 google-auth-2.36.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.62.3 h5py-3.8.0 keras-2.11.0 libclang-18.1.1 markdown-3.4.4 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-2.0.0 rsa-4.9 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0 urllib3-2.0.7 werkzeug-2.2.3 wrapt-1.16.0
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: keras in f:\coding\ds_projects\venv\lib\site-packages (2.11.0)
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-win_amd64.whl.metadata (6.7 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.38.0-py3-none-any.whl.metadata (138 kB)
#      -------------------------------------- 138.5/138.5 kB 4.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp37-cp37m-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.17 in f:\coding\ds_projects\venv\lib\site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in f:\coding\ds_projects\venv\lib\site-packages (from matplotlib) (24.0)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading Pillow-9.5.0-cp37-cp37m-win_amd64.whl.metadata (9.7 kB)
# Collecting pyparsing>=2.2.1 (from matplotlib)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in f:\coding\ds_projects\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in f:\coding\ds_projects\venv\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (4.7.1)
# Requirement already satisfied: six>=1.5 in f:\coding\ds_projects\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 7.2/7.2 MB 24.3 MB/s eta 0:00:00
# Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#    ---------------------------------------- 965.4/965.4 kB 3.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp37-cp37m-win_amd64.whl (55 kB)
#    ---------------------------------------- 55.8/55.8 kB 3.0 MB/s eta 0:00:00
# Downloading Pillow-9.5.0-cp37-cp37m-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 2.5/2.5 MB 4.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ---------------------------------------- 104.1/104.1 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.38.0 kiwisolver-1.4.5 matplotlib-3.5.3 pillow-9.5.0 pyparsing-3.1.4
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Set Random Seed for Reproducibility

# %%
np.random.seed(42)
tf.random.set_seed(42)
batch_size = 64

# %% [markdown]
# # 2. Load and Preprocess the MNIST Dataset

# %%
# Load the MNIST dataset
(x_train, y_train_orig), (x_test, y_test_orig) = keras.datasets.mnist.load_data()

# Normalize the images to [0, 1] range and flatten them
x_train = x_train.astype('float32') / 255.0
x_train_flat = x_train.reshape(-1, 28 * 28)
x_test = x_test.astype('float32') / 255.0
x_test_flat = x_test.reshape(-1, 28 * 28)

# Convert labels to one-hot encoded vectors
num_classes = 10
y_train = keras.utils.to_categorical(y_train_orig, num_classes)
y_test = keras.utils.to_categorical(y_test_orig, num_classes)

# %% [markdown]
# # 3. Hyperparameters

# %%
''' TODO: Adjust the following parameters with different values. Save the plots and test results for each setup.
    TODO: write a report about your findings from varying the parameters and their effect on overall performance. '''

# lr: 0.1, 0.01, ...
# epoch: 5, 10, 50, ...
# layer: [128], [256, 256], ... .
learning_rate = 0.01
num_epochs = 5
hidden_layers = [128]

# %% [markdown]
# # 4. Define the Neural Network Model

# %%
def create_mlp_model(input_size, hidden_layers, output_size):
    model = keras.Sequential()

    # Input layer is defined by specifying input_shape in the first layer
    for i, units in enumerate(hidden_layers):
        if i == 0:
            # First hidden layer with input shape specified
            model.add(layers.Dense(units, activation='relu', input_shape=(input_size,)))
        else:
            # Subsequent hidden layers
            model.add(layers.Dense(units, activation='relu'))

    # Output layer with softmax activation for multi-class classification
    model.add(layers.Dense(output_size, activation='softmax'))

    return model

# Model parameters
input_size = 28 * 28  # MNIST images are 28x28 pixels
output_size = num_classes  # 10 classes for digits 0-9

# Create the model
model = create_mlp_model(input_size, hidden_layers, output_size)

# %% [markdown]
# # 5. Compile the Model

# %%
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=learning_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # 6. Train the Model

# %%
history = model.fit(
    x_train_flat, y_train,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_split=0.1,  # Use 10% of training data for validation
    verbose=1
)
# Out:
# Epoch 1/5
# 844/844 [==============================] - 4s 3ms/step - loss: 0.9602 - accuracy: 0.7694 - val_loss: 0.4395 - val_accuracy: 0.8977
# Epoch 2/5
# 844/844 [==============================] - 2s 2ms/step - loss: 0.4448 - accuracy: 0.8829 - val_loss: 0.3267 - val_accuracy: 0.9178
# Epoch 3/5
# 844/844 [==============================] - 2s 2ms/step - loss: 0.3716 - accuracy: 0.8982 - val_loss: 0.2873 - val_accuracy: 0.9227
# Epoch 4/5
# 844/844 [==============================] - 2s 2ms/step - loss: 0.3363 - accuracy: 0.9054 - val_loss: 0.2633 - val_accuracy: 0.9275
# Epoch 5/5
# 844/844 [==============================] - 2s 2ms/step - loss: 0.3123 - accuracy: 0.9126 - val_loss: 0.2475 - val_accuracy: 0.9318

# %% [markdown]
# # 7. Evaluate the Model on Test Data

# %%
test_loss, test_accuracy = model.evaluate(x_test_flat, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Test Accuracy: 91.98%

# %% [markdown]
# # 8. Visualize Training History

# %%
plt.figure(figsize=(12, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Test the Model on Random Input Data

# %%
# Select random samples from the test set
num_samples = 5
random_indices = np.random.choice(x_test.shape[0], num_samples, replace=False)
random_images = x_test[random_indices]
random_images_flat = x_test_flat[random_indices]
random_labels = y_test_orig[random_indices]

# Predict the labels of the random images
predictions = model.predict(random_images_flat)
predicted_labels = np.argmax(predictions, axis=1)

# Plot the random images along with predicted and true labels
plt.figure(figsize=(15, 3))
for i in range(num_samples):
    plt.subplot(1, num_samples, i+1)
    plt.imshow(random_images[i], cmap='gray')
    plt.title(f"True: {random_labels[i]}\nPredicted: {predicted_labels[i]}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 87ms/step
